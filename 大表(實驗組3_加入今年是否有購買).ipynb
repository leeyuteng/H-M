# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open ('df.pickle','rb') as fr:
    df = pickle.load(fr)

# %%
df
# Out:
#                                                 customer_id  article_id  Buy  \
# 0         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0562245001    0
# 1         00007d2de826758b65a93dd24ce629ed66842531df6699...  0562245001    0
# 2         00009d946eec3ea54add5ba56d5210ea898def4b46c685...  0562245001    0
# 3         0000b2f1829e23b24feec422ef13df3ccedaedc85368e6...  0562245001    0
# 4         00015c1a121e08bbd2552c15fbbb6e6b19d3bf8f7b6a3d...  0562245001    0
# ...                                                     ...         ...  ...
# 55945779  fffe836e77106fde6a3d0fd74882c4f4315c5255e38fd1...  0688341001    0
# 55945780  ffff12aa623c69eae8959d673f1f12ad0194ad760d77fd...  0688341001    0
# 55945781  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0688341001    0
# 55945782  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...  0688341001    0
# 55945783  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0688341001    0
#
#              price  FN  Active club_member_status fashion_news_frequency  \
# 0         0.033881   0       0             ACTIVE                   None
# 1         0.033881   1       1             ACTIVE              Regularly
# 2         0.033881   1       1             ACTIVE              Regularly
# 3         0.033881   1       1             ACTIVE              Regularly
# 4         0.033881   0       0             ACTIVE                   None
# ...            ...  ..     ...                ...                    ...
# 55945779  0.016932   1       1             ACTIVE              Regularly
# 55945780  0.016932   0       0             ACTIVE                   None
# 55945781  0.016932   0       0             ACTIVE                   None
# 55945782  0.016932   0       0             ACTIVE                   None
# 55945783  0.016932   1       1             ACTIVE              Regularly
#
#           age_class attribute  ... product_type_name  product_group_name  \
# 0                 1     Woman  ...          Trousers  Garment Lower body
# 1                 2     Woman  ...          Trousers  Garment Lower body
# 2                 5     Woman  ...          Trousers  Garment Lower body
# 3                 4     Woman  ...          Trousers  Garment Lower body
# 4                 1     Woman  ...          Trousers  Garment Lower body
# ...             ...       ...  ...               ...                 ...
# 55945779          2     Woman  ...           T-shirt  Garment Upper body
# 55945780          2     Woman  ...           T-shirt  Garment Upper body
# 55945781          4     Young  ...           T-shirt  Garment Upper body
# 55945782          1     Young  ...           T-shirt  Garment Upper body
# 55945783          1     Woman  ...           T-shirt  Garment Upper body
#
#          graphical_appearance_name colour_group_name  \
# 0                            Solid             Black
# 1                            Solid             Black
# 2                            Solid             Black
# 3                            Solid             Black
# 4                            Solid             Black
# ...                            ...               ...
# 55945779                     Solid             Black
# 55945780                     Solid             Black
# 55945781                     Solid             Black
# 55945782                     Solid             Black
# 55945783                     Solid             Black
#
#          perceived_colour_value_name department_name  index_name  \
# 0                               Dark         Trouser  Ladieswear
# 1                               Dark         Trouser  Ladieswear
# 2                               Dark         Trouser  Ladieswear
# 3                               Dark         Trouser  Ladieswear
# 4                               Dark         Trouser  Ladieswear
# ...                              ...             ...         ...
# 55945779                        Dark    Jersey Basic  Ladieswear
# 55945780                        Dark    Jersey Basic  Ladieswear
# 55945781                        Dark    Jersey Basic  Ladieswear
# 55945782                        Dark    Jersey Basic  Ladieswear
# 55945783                        Dark    Jersey Basic  Ladieswear
#
#          index_group_name                section_name garment_group_name
# 0              Ladieswear  Womens Everyday Collection           Trousers
# 1              Ladieswear  Womens Everyday Collection           Trousers
# 2              Ladieswear  Womens Everyday Collection           Trousers
# 3              Ladieswear  Womens Everyday Collection           Trousers
# 4              Ladieswear  Womens Everyday Collection           Trousers
# ...                   ...                         ...                ...
# 55945779       Ladieswear      Womens Everyday Basics       Jersey Basic
# 55945780       Ladieswear      Womens Everyday Basics       Jersey Basic
# 55945781       Ladieswear      Womens Everyday Basics       Jersey Basic
# 55945782       Ladieswear      Womens Everyday Basics       Jersey Basic
# 55945783       Ladieswear      Womens Everyday Basics       Jersey Basic
#
# [55945784 rows x 21 columns]

# %%
cus = df.groupby('customer_id')['Buy'].sum()
cus = pd.DataFrame(cus)
cus.reset_index(inplace=True)
cus
# Out:
#                                               customer_id  Buy
# 0       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...    4
# 1       00007d2de826758b65a93dd24ce629ed66842531df6699...    6
# 2       00009d946eec3ea54add5ba56d5210ea898def4b46c685...    7
# 3       0000b2f1829e23b24feec422ef13df3ccedaedc85368e6...    2
# 4       00015c1a121e08bbd2552c15fbbb6e6b19d3bf8f7b6a3d...    3
# ...                                                   ...  ...
# 229281  fffe836e77106fde6a3d0fd74882c4f4315c5255e38fd1...    3
# 229282  ffff12aa623c69eae8959d673f1f12ad0194ad760d77fd...    1
# 229283  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...    1
# 229284  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...    5
# 229285  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...    4
#
# [229286 rows x 2 columns]

# %%
cus_alive = pd.read_csv('cus_alive.csv')

# %%
cus_alive
# Out:
#                                               customer_id  alive
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...      1
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...      1
# 2       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...      1
# 3       00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...      1
# 4       0000757967448a6cb83efb3ea7a3fb9d418ac7adf2379d...      1
# ...                                                   ...    ...
# 862719  ffff8f9ecdce722b5bab97fff68a6d1866492209bfe524...      1
# 862720  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...      1
# 862721  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...      1
# 862722  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...      1
# 862723  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...      1
#
# [862724 rows x 2 columns]

# %%
cus = pd.merge(cus,cus_alive,on='customer_id',how="left")
cus
# Out:
#                                               customer_id  Buy  alive
# 0       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...    4    1.0
# 1       00007d2de826758b65a93dd24ce629ed66842531df6699...    6    1.0
# 2       00009d946eec3ea54add5ba56d5210ea898def4b46c685...    7    1.0
# 3       0000b2f1829e23b24feec422ef13df3ccedaedc85368e6...    2    1.0
# 4       00015c1a121e08bbd2552c15fbbb6e6b19d3bf8f7b6a3d...    3    1.0
# ...                                                   ...  ...    ...
# 229281  fffe836e77106fde6a3d0fd74882c4f4315c5255e38fd1...    3    1.0
# 229282  ffff12aa623c69eae8959d673f1f12ad0194ad760d77fd...    1    1.0
# 229283  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...    1    NaN
# 229284  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...    5    1.0
# 229285  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...    4    1.0
#
# [229286 rows x 3 columns]

# %%
cus.alive = cus.alive.fillna(0)
cus.drop('Buy',axis=1,inplace=True)
cus
# Out:
#                                               customer_id  alive
# 0       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...    1.0
# 1       00007d2de826758b65a93dd24ce629ed66842531df6699...    1.0
# 2       00009d946eec3ea54add5ba56d5210ea898def4b46c685...    1.0
# 3       0000b2f1829e23b24feec422ef13df3ccedaedc85368e6...    1.0
# 4       00015c1a121e08bbd2552c15fbbb6e6b19d3bf8f7b6a3d...    1.0
# ...                                                   ...    ...
# 229281  fffe836e77106fde6a3d0fd74882c4f4315c5255e38fd1...    1.0
# 229282  ffff12aa623c69eae8959d673f1f12ad0194ad760d77fd...    1.0
# 229283  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...    0.0
# 229284  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...    1.0
# 229285  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...    1.0
#
# [229286 rows x 2 columns]

# %%
cus['alive'].value_counts()
# Out:
# 1.0    202995
# 0.0     26291
# Name: alive, dtype: int64

# %%
df = pd.merge(df,cus,on="customer_id",how='inner')

# %%
df
# Out:
#                                                 customer_id  article_id  Buy  \
# 0         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0562245001    0
# 1         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0399223001    0
# 2         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0562245018    0
# 3         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0610776002    0
# 4         0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  0484398001    0
# ...                                                     ...         ...  ...
# 55945779  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0417951001    0
# 55945780  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0395127001    0
# 55945781  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0664074007    0
# 55945782  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0695632001    0
# 55945783  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  0688341001    0
#
#              price  FN  Active club_member_status fashion_news_frequency  \
# 0         0.033881   0       0             ACTIVE                   None
# 1         0.033983   0       0             ACTIVE                   None
# 2         0.033881   0       0             ACTIVE                   None
# 3         0.032186   0       0             ACTIVE                   None
# 4         0.033881   0       0             ACTIVE                   None
# ...            ...  ..     ...                ...                    ...
# 55945779  0.016932   1       1             ACTIVE              Regularly
# 55945780  0.042356   1       1             ACTIVE              Regularly
# 55945781  0.025407   1       1             ACTIVE              Regularly
# 55945782  0.033881   1       1             ACTIVE              Regularly
# 55945783  0.016932   1       1             ACTIVE              Regularly
#
#           age_class attribute  ...  product_group_name  \
# 0                 1     Woman  ...  Garment Lower body
# 1                 1     Woman  ...  Garment Lower body
# 2                 1     Woman  ...  Garment Lower body
# 3                 1     Woman  ...  Garment Upper body
# 4                 1     Woman  ...  Garment Lower body
# ...             ...       ...  ...                 ...
# 55945779          1     Woman  ...      Socks & Tights
# 55945780          1     Woman  ...  Garment Upper body
# 55945781          1     Woman  ...  Garment Upper body
# 55945782          1     Woman  ...  Garment Upper body
# 55945783          1     Woman  ...  Garment Upper body
#
#          graphical_appearance_name colour_group_name  \
# 0                            Solid             Black
# 1                            Solid             Black
# 2                            Denim              Blue
# 3                            Solid             Black
# 4                            Solid             Black
# ...                            ...               ...
# 55945779                     Solid             Beige
# 55945780                     Solid             White
# 55945781                     Solid             White
# 55945782                     Solid             Black
# 55945783                     Solid             Black
#
#          perceived_colour_value_name       department_name        index_name  \
# 0                               Dark               Trouser        Ladieswear
# 1                               Dark        Denim Trousers           Divided
# 2                        Dusty Light               Trouser        Ladieswear
# 3                               Dark          Jersey Basic        Ladieswear
# 4                               Dark  Ladies Sport Bottoms             Sport
# ...                              ...                   ...               ...
# 55945779                Medium Dusty          Tights basic  Lingeries/Tights
# 55945780                       Light             Shirt S&T          Menswear
# 55945781                       Light                Jersey        Ladieswear
# 55945782                        Dark                Blouse        Ladieswear
# 55945783                        Dark          Jersey Basic        Ladieswear
#
#          index_group_name                    section_name garment_group_name  \
# 0              Ladieswear      Womens Everyday Collection           Trousers
# 1                 Divided                    Ladies Denim     Trousers Denim
# 2              Ladieswear      Womens Everyday Collection           Trousers
# 3              Ladieswear          Womens Everyday Basics       Jersey Basic
# 4                   Sport                Ladies H&M Sport       Jersey Fancy
# ...                   ...                             ...                ...
# 55945779       Ladieswear  Womens Nightwear, Socks & Tigh   Socks and Tights
# 55945780         Menswear           Men Suits & Tailoring             Shirts
# 55945781       Ladieswear                Womens Tailoring       Jersey Fancy
# 55945782       Ladieswear                Womens Tailoring            Blouses
# 55945783       Ladieswear          Womens Everyday Basics       Jersey Basic
#
#          alive
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ...        ...
# 55945779   1.0
# 55945780   1.0
# 55945781   1.0
# 55945782   1.0
# 55945783   1.0
#
# [55945784 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55945784 entries, 0 to 55945783
# Data columns (total 22 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   customer_id                  object
#  1   article_id                   object
#  2   Buy                          uint8
#  3   price                        float64
#  4   FN                           uint8
#  5   Active                       uint8
#  6   club_member_status           object
#  7   fashion_news_frequency       object
#  8   age_class                    uint8
#  9   attribute                    object
#  10  prod_name                    object
#  11  product_type_name            object
#  12  product_group_name           object
#  13  graphical_appearance_name    object
#  14  colour_group_name            object
#  15  perceived_colour_value_name  object
#  16  department_name              object
#  17  index_name                   object
#  18  index_group_name             object
#  19  section_name                 object
#  20  garment_group_name           object
#  21  alive                        float64
# dtypes: float64(2), object(16), uint8(4)
# memory usage: 8.1+ GB

# %%
df.drop(['price'],axis = 1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55945784 entries, 0 to 55945783
# Data columns (total 21 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   customer_id                  object
#  1   article_id                   object
#  2   Buy                          uint8
#  3   FN                           uint8
#  4   Active                       uint8
#  5   club_member_status           object
#  6   fashion_news_frequency       object
#  7   age_class                    uint8
#  8   attribute                    object
#  9   prod_name                    object
#  10  product_type_name            object
#  11  product_group_name           object
#  12  graphical_appearance_name    object
#  13  colour_group_name            object
#  14  perceived_colour_value_name  object
#  15  department_name              object
#  16  index_name                   object
#  17  index_group_name             object
#  18  section_name                 object
#  19  garment_group_name           object
#  20  alive                        float64
# dtypes: float64(1), object(16), uint8(4)
# memory usage: 7.7+ GB

# %%
#label_encoding
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['club_member_status'] = labelencoder.fit_transform(df['club_member_status'])
df['fashion_news_frequency'] = labelencoder.fit_transform(df['fashion_news_frequency'])
df['index_name'] = labelencoder.fit_transform(df['index_name'])
df['attribute'] = labelencoder.fit_transform(df['attribute'])
df['perceived_colour_value_name'] = labelencoder.fit_transform(df['perceived_colour_value_name'])
df['colour_group_name'] = labelencoder.fit_transform(df['colour_group_name'])
df['graphical_appearance_name'] = labelencoder.fit_transform(df['graphical_appearance_name'])
df['prod_name'] = labelencoder.fit_transform(df['prod_name'])
df['product_type_name'] = labelencoder.fit_transform(df['product_type_name'])
df['product_group_name'] = labelencoder.fit_transform(df['product_group_name'])
df['department_name'] = labelencoder.fit_transform(df['department_name'])
df['index_group_name'] = labelencoder.fit_transform(df['index_group_name'])
df['section_name'] = labelencoder.fit_transform(df['section_name'])
df['garment_group_name'] = labelencoder.fit_transform(df['garment_group_name'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55945784 entries, 0 to 55945783
# Data columns (total 21 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   customer_id                  object
#  1   article_id                   object
#  2   Buy                          uint8
#  3   FN                           uint8
#  4   Active                       uint8
#  5   club_member_status           int32
#  6   fashion_news_frequency       int32
#  7   age_class                    uint8
#  8   attribute                    int32
#  9   prod_name                    int32
#  10  product_type_name            int32
#  11  product_group_name           int32
#  12  graphical_appearance_name    int32
#  13  colour_group_name            int32
#  14  perceived_colour_value_name  int32
#  15  department_name              int32
#  16  index_name                   int32
#  17  index_group_name             int32
#  18  section_name                 int32
#  19  garment_group_name           int32
#  20  alive                        float64
# dtypes: float64(1), int32(14), object(2), uint8(4)
# memory usage: 4.8+ GB

# %%
df['club_member_status'] = df['club_member_status'].astype('uint8')
df['fashion_news_frequency'] = df['fashion_news_frequency'].astype('uint8')
df['prod_name'] = df['prod_name'].astype('uint8')
df['product_type_name'] = df['product_type_name'].astype('uint8')
df['product_group_name'] = df['product_group_name'].astype('uint8')
df['graphical_appearance_name'] = df['graphical_appearance_name'].astype('uint8')
df['colour_group_name'] = df['colour_group_name'].astype('uint8')
df['perceived_colour_value_name'] = df['perceived_colour_value_name'].astype('uint8')
df['department_name'] = df['department_name'].astype('uint8')
df['index_name'] = df['index_name'].astype('uint8')
df['index_group_name'] = df['index_group_name'].astype('uint8')
df['section_name'] = df['section_name'].astype('uint8')
df['garment_group_name'] = df['garment_group_name'].astype('uint8')
df['attribute'] = df['attribute'].astype('uint8')
df['alive'] = df['alive'].astype('uint8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55945784 entries, 0 to 55945783
# Data columns (total 21 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   customer_id                  object
#  1   article_id                   object
#  2   Buy                          uint8
#  3   FN                           uint8
#  4   Active                       uint8
#  5   club_member_status           uint8
#  6   fashion_news_frequency       uint8
#  7   age_class                    uint8
#  8   attribute                    uint8
#  9   prod_name                    uint8
#  10  product_type_name            uint8
#  11  product_group_name           uint8
#  12  graphical_appearance_name    uint8
#  13  colour_group_name            uint8
#  14  perceived_colour_value_name  uint8
#  15  department_name              uint8
#  16  index_name                   uint8
#  17  index_group_name             uint8
#  18  section_name                 uint8
#  19  garment_group_name           uint8
#  20  alive                        uint8
# dtypes: object(2), uint8(19)
# memory usage: 2.2+ GB

# %%
mask = (df["alive"] == 0)
mask2 = (df["Buy"] == 0)
df[(mask & mask2)]
# Out:
#                                                 customer_id  article_id  Buy  \
# 1952      00029b1b57c1aec110f48aac6639d71369387c5985cbd8...  0562245001    0
# 1953      00029b1b57c1aec110f48aac6639d71369387c5985cbd8...  0399223001    0
# 1954      00029b1b57c1aec110f48aac6639d71369387c5985cbd8...  0562245018    0
# 1955      00029b1b57c1aec110f48aac6639d71369387c5985cbd8...  0610776002    0
# 1956      00029b1b57c1aec110f48aac6639d71369387c5985cbd8...  0484398001    0
# ...                                                     ...         ...  ...
# 55945291  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0417951001    0
# 55945292  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0395127001    0
# 55945293  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0664074007    0
# 55945294  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0695632001    0
# 55945295  ffff1c80bd2dede87deda612527c3df06d2fb270b85602...  0688341001    0
#
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 1952       0       0                   0                       1          1
# 1953       0       0                   0                       1          1
# 1954       0       0                   0                       1          1
# 1955       0       0                   0                       1          1
# 1956       0       0                   0                       1          1
# ...       ..     ...                 ...                     ...        ...
# 55945291   0       0                   0                       1          4
# 55945292   0       0                   0                       1          4
# 55945293   0       0                   0                       1          4
# 55945294   0       0                   0                       1          4
# 55945295   0       0                   0                       1          4
#
#           attribute  prod_name  ...  product_group_name  \
# 1952              4        115  ...                   2
# 1953              4         59  ...                   2
# 1954              4        115  ...                   2
# 1955              4        182  ...                   3
# 1956              4        149  ...                   2
# ...             ...        ...  ...                 ...
# 55945291          4        173  ...                   6
# 55945292          4         40  ...                   3
# 55945293          4         44  ...                   3
# 55945294          4         80  ...                   3
# 55945295          4         30  ...                   3
#
#           graphical_appearance_name  colour_group_name  \
# 1952                              8                  1
# 1953                              8                  1
# 1954                              2                  2
# 1955                              8                  1
# 1956                              8                  1
# ...                             ...                ...
# 55945291                          8                  0
# 55945292                          8                 14
# 55945293                          8                 14
# 55945294                          8                  1
# 55945295                          8                  1
#
#           perceived_colour_value_name  department_name  index_name  \
# 1952                                0               43           3
# 1953                                0                8           1
# 1954                                1               43           3
# 1955                                0               18           3
# 1956                                0               24           6
# ...                               ...              ...         ...
# 55945291                            4               41           4
# 55945292                            2               30           5
# 55945293                            2               17           3
# 55945294                            0                3           3
# 55945295                            0               18           3
#
#           index_group_name  section_name  garment_group_name  alive
# 1952                     2            15                  14      0
# 1953                     1             7                  15      0
# 1954                     2            15                  14      0
# 1955                     2            14                   4      0
# 1956                     4             8                   5      0
# ...                    ...           ...                 ...    ...
# 55945291                 2            17                  11      0
# 55945292                 3            10                   7      0
# 55945293                 2            21                   5      0
# 55945294                 2            21                   1      0
# 55945295                 2            14                   4      0
#
# [6337408 rows x 21 columns]

# %%
#匯出pickle
import pickle
with open('df2.pickle','wb') as fw:
    pickle.dump(df,fw)

# %% [markdown]
# # 切訓練測試

# %%
y=df['Buy']
data=df.drop(['customer_id','article_id','Buy'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, y,test_size=0.33, random_state=101)

# %%
undersampling = pd.concat([X_train,y_train],axis=1)
undersampling
# Out:
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 25466664   1       1                   0                       2          2
# 26629413   0       0                   0                       1          1
# 35783730   1       1                   0                       2          2
# 51504966   1       1                   0                       2          1
# 12119477   0       0                   0                       1          2
# ...       ..     ...                 ...                     ...        ...
# 311895     0       0                   0                       1          5
# 55187007   0       0                   0                       1          1
# 35079505   0       0                   0                       1          4
# 24331787   0       0                   0                       1          1
# 3322719    1       1                   0                       2          2
#
#           attribute  prod_name  product_type_name  product_group_name  \
# 25466664          3        104                  7                   8
# 26629413          3        118                 31                   6
# 35783730          3         95                  6                   5
# 51504966          4         64                 35                   3
# 12119477          3         44                 29                   3
# ...             ...        ...                ...                 ...
# 311895            3        151                  5                   3
# 55187007          3        151                  5                   3
# 35079505          3         54                 31                   6
# 24331787          3         96                 23                   2
# 3322719           3         72                  2                   0
#
#           graphical_appearance_name  colour_group_name  \
# 25466664                          8                 14
# 26629413                          8                  1
# 35783730                          8                  1
# 51504966                          8                  1
# 12119477                          8                 14
# ...                             ...                ...
# 311895                            8                 14
# 55187007                          8                 14
# 35079505                          8                  1
# 24331787                          8                  1
# 3322719                           8                  1
#
#           perceived_colour_value_name  department_name  index_name  \
# 25466664                            2                6           4
# 26629413                            0               41           4
# 35783730                            0                9           1
# 51504966                            0               26           5
# 12119477                            2               17           3
# ...                               ...              ...         ...
# 311895                              2                3           3
# 55187007                            2                3           3
# 35079505                            0               41           4
# 24331787                            0                1           1
# 3322719                             0                2           2
#
#           index_group_name  section_name  garment_group_name  alive  Buy
# 25466664                 2            16                  16      1    0
# 26629413                 2            17                  11      1    0
# 35783730                 1             2                   8      1    0
# 51504966                 3            11                   4      1    0
# 12119477                 2            21                   5      1    0
# ...                    ...           ...                 ...    ...  ...
# 311895                   2            21                   1      1    0
# 55187007                 2            21                   1      1    0
# 35079505                 2            17                  11      1    0
# 24331787                 1             3                   4      1    0
# 3322719                  2            12                   0      0    0
#
# [37483675 rows x 19 columns]

# %%
#篩選0的資料
undersampling_0 = undersampling[undersampling['Buy']==0]
undersampling_0
# Out:
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 25466664   1       1                   0                       2          2
# 26629413   0       0                   0                       1          1
# 35783730   1       1                   0                       2          2
# 51504966   1       1                   0                       2          1
# 12119477   0       0                   0                       1          2
# ...       ..     ...                 ...                     ...        ...
# 311895     0       0                   0                       1          5
# 55187007   0       0                   0                       1          1
# 35079505   0       0                   0                       1          4
# 24331787   0       0                   0                       1          1
# 3322719    1       1                   0                       2          2
#
#           attribute  prod_name  product_type_name  product_group_name  \
# 25466664          3        104                  7                   8
# 26629413          3        118                 31                   6
# 35783730          3         95                  6                   5
# 51504966          4         64                 35                   3
# 12119477          3         44                 29                   3
# ...             ...        ...                ...                 ...
# 311895            3        151                  5                   3
# 55187007          3        151                  5                   3
# 35079505          3         54                 31                   6
# 24331787          3         96                 23                   2
# 3322719           3         72                  2                   0
#
#           graphical_appearance_name  colour_group_name  \
# 25466664                          8                 14
# 26629413                          8                  1
# 35783730                          8                  1
# 51504966                          8                  1
# 12119477                          8                 14
# ...                             ...                ...
# 311895                            8                 14
# 55187007                          8                 14
# 35079505                          8                  1
# 24331787                          8                  1
# 3322719                           8                  1
#
#           perceived_colour_value_name  department_name  index_name  \
# 25466664                            2                6           4
# 26629413                            0               41           4
# 35783730                            0                9           1
# 51504966                            0               26           5
# 12119477                            2               17           3
# ...                               ...              ...         ...
# 311895                              2                3           3
# 55187007                            2                3           3
# 35079505                            0               41           4
# 24331787                            0                1           1
# 3322719                             0                2           2
#
#           index_group_name  section_name  garment_group_name  alive  Buy
# 25466664                 2            16                  16      1    0
# 26629413                 2            17                  11      1    0
# 35783730                 1             2                   8      1    0
# 51504966                 3            11                   4      1    0
# 12119477                 2            21                   5      1    0
# ...                    ...           ...                 ...    ...  ...
# 311895                   2            21                   1      1    0
# 55187007                 2            21                   1      1    0
# 35079505                 2            17                  11      1    0
# 24331787                 1             3                   4      1    0
# 3322719                  2            12                   0      0    0
#
# [36854710 rows x 19 columns]

# %%
#篩選1的資料
undersampling_1 = undersampling[undersampling['Buy']==1]
undersampling_1
# Out:
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 15792837   1       1                   0                       2          2
# 47780350   1       1                   0                       2          5
# 37632437   1       1                   0                       2          4
# 26824951   1       1                   0                       2          1
# 42856310   0       0                   0                       1          2
# ...       ..     ...                 ...                     ...        ...
# 21347134   0       0                   0                       1          4
# 47800705   0       0                   0                       1          4
# 14788690   0       0                   3                       1          4
# 21288864   0       0                   0                       1          2
# 12023355   0       0                   0                       1          3
#
#           attribute  prod_name  product_type_name  product_group_name  \
# 15792837          3        134                 19                   3
# 47780350          3         42                  8                   3
# 37632437          3        168                 25                   6
# 26824951          3         83                 31                   6
# 42856310          3         49                 32                   8
# ...             ...        ...                ...                 ...
# 21347134          3         65                 35                   3
# 47800705          3         44                 29                   3
# 14788690          3        115                 30                   2
# 21288864          3         15                 25                   6
# 12023355          1         15                 25                   6
#
#           graphical_appearance_name  colour_group_name  \
# 15792837                          8                  1
# 47780350                          8                  1
# 37632437                          8                  1
# 26824951                          0                  1
# 42856310                          8                  1
# ...                             ...                ...
# 21347134                          8                  1
# 47800705                          8                  1
# 14788690                          8                 14
# 21288864                          8                 14
# 12023355                          8                  1
#
#           perceived_colour_value_name  department_name  index_name  \
# 15792837                            0                1           1
# 47780350                            0               22           3
# 37632437                            0               32           4
# 26824951                            0               41           4
# 42856310                            0               12           4
# ...                               ...              ...         ...
# 21347134                            0               17           3
# 47800705                            0               17           3
# 14788690                            2               43           3
# 21288864                            2               32           4
# 12023355                            0               32           4
#
#           index_group_name  section_name  garment_group_name  alive  Buy
# 15792837                 1             3                   4      1    1
# 47780350                 2            21                   6      1    1
# 37632437                 2            17                  11      1    1
# 26824951                 2            17                  11      0    1
# 42856310                 2            16                  16      1    1
# ...                    ...           ...                 ...    ...  ...
# 21347134                 2            13                   5      1    1
# 47800705                 2            21                   5      1    1
# 14788690                 2            15                  14      0    1
# 21288864                 2            17                  11      1    1
# 12023355                 2            17                  11      1    1
#
# [628965 rows x 19 columns]

# %%
#打亂資料
from sklearn.utils import shuffle
undersampling_0 = shuffle(undersampling_0)
undersampling_0.head()
# Out:
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 21082074   0       0                   0                       1          3
# 43062546   1       1                   0                       2          2
# 2039234    1       1                   0                       2          4
# 28395888   0       0                   0                       1          2
# 42092180   0       0                   0                       1          1
#
#           attribute  prod_name  product_type_name  product_group_name  \
# 21082074          3         13                 13                   0
# 43062546          3        139                 28                   3
# 2039234           3         39                 27                   7
# 28395888          3         86                  1                   5
# 42092180          4        164                 30                   2
#
#           graphical_appearance_name  colour_group_name  \
# 21082074                         10                 16
# 43062546                          8                 14
# 2039234                           8                  1
# 28395888                          8                  1
# 42092180                          2                 14
#
#           perceived_colour_value_name  department_name  index_name  \
# 21082074                            0               15           2
# 43062546                            2               18           5
# 2039234                             0               40           4
# 28395888                            0               13           2
# 42092180                            2                8           1
#
#           index_group_name  section_name  garment_group_name  alive  Buy
# 21082074                 2            19                   0      1    0
# 43062546                 3            11                   4      1    0
# 2039234                  2            20                  13      1    0
# 28395888                 2            18                   8      1    0
# 42092180                 1             7                  15      1    0

# %%
undersampling_1['Buy'].value_counts()
# Out:
# 1    628965
# Name: Buy, dtype: int64

# %%
#取樣
under=undersampling_0.sample(n=628965,random_state=123,axis=0,replace=False)

# %%
under
# Out:
#           FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 19934506   0       0                   0                       1          2
# 33043785   0       0                   0                       1          2
# 50695498   1       1                   0                       2          5
# 47520556   0       0                   0                       1          3
# 10111858   0       0                   0                       1          2
# ...       ..     ...                 ...                     ...        ...
# 12134401   0       0                   0                       1          2
# 37700678   0       0                   0                       1          2
# 54695731   1       1                   0                       2          1
# 27366692   1       1                   0                       2          1
# 4799614    1       1                   0                       2          2
#
#           attribute  prod_name  product_type_name  product_group_name  \
# 19934506          3         74                  1                   5
# 33043785          3        108                 29                   3
# 50695498          3        193                 30                   2
# 47520556          3        126                 30                   2
# 10111858          3        113                 17                   2
# ...             ...        ...                ...                 ...
# 12134401          3         19                 20                   4
# 37700678          3        137                 35                   3
# 54695731          4         91                 33                   8
# 27366692          3        104                  7                   8
# 4799614           3        189                 28                   3
#
#           graphical_appearance_name  colour_group_name  \
# 19934506                          8                  1
# 33043785                          8                  1
# 50695498                          8                  1
# 47520556                          8                  1
# 10111858                          8                  1
# ...                             ...                ...
# 12134401                          8                  1
# 37700678                          8                  1
# 54695731                          8                  1
# 27366692                          8                 14
# 4799614                           8                 14
#
#           perceived_colour_value_name  department_name  index_name  \
# 19934506                            0               13           2
# 33043785                            0               18           3
# 50695498                            0               43           3
# 47520556                            0               43           3
# 10111858                            0               18           3
# ...                               ...              ...         ...
# 12134401                            0               28           4
# 37700678                            0                3           3
# 54695731                            0               14           4
# 27366692                            2                6           4
# 4799614                             2               26           5
#
#           index_group_name  section_name  garment_group_name  alive  Buy
# 19934506                 2            18                   8      1    0
# 33043785                 2            14                   4      1    0
# 50695498                 2            21                  14      1    0
# 47520556                 2            21                  14      1    0
# 10111858                 2            14                   4      1    0
# ...                    ...           ...                 ...    ...  ...
# 12134401                 2            17                  16      1    0
# 37700678                 2            15                   1      1    0
# 54695731                 2            16                  16      1    0
# 27366692                 2            16                  16      1    0
# 4799614                  3            11                   4      0    0
#
# [628965 rows x 19 columns]

# %%
#合併0和1
under = pd.concat([under,undersampling_1],ignore_index=True)
under
# Out:
#          FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 0         0       0                   0                       1          2
# 1         0       0                   0                       1          2
# 2         1       1                   0                       2          5
# 3         0       0                   0                       1          3
# 4         0       0                   0                       1          2
# ...      ..     ...                 ...                     ...        ...
# 1257925   0       0                   0                       1          4
# 1257926   0       0                   0                       1          4
# 1257927   0       0                   3                       1          4
# 1257928   0       0                   0                       1          2
# 1257929   0       0                   0                       1          3
#
#          attribute  prod_name  product_type_name  product_group_name  \
# 0                3         74                  1                   5
# 1                3        108                 29                   3
# 2                3        193                 30                   2
# 3                3        126                 30                   2
# 4                3        113                 17                   2
# ...            ...        ...                ...                 ...
# 1257925          3         65                 35                   3
# 1257926          3         44                 29                   3
# 1257927          3        115                 30                   2
# 1257928          3         15                 25                   6
# 1257929          1         15                 25                   6
#
#          graphical_appearance_name  colour_group_name  \
# 0                                8                  1
# 1                                8                  1
# 2                                8                  1
# 3                                8                  1
# 4                                8                  1
# ...                            ...                ...
# 1257925                          8                  1
# 1257926                          8                  1
# 1257927                          8                 14
# 1257928                          8                 14
# 1257929                          8                  1
#
#          perceived_colour_value_name  department_name  index_name  \
# 0                                  0               13           2
# 1                                  0               18           3
# 2                                  0               43           3
# 3                                  0               43           3
# 4                                  0               18           3
# ...                              ...              ...         ...
# 1257925                            0               17           3
# 1257926                            0               17           3
# 1257927                            2               43           3
# 1257928                            2               32           4
# 1257929                            0               32           4
#
#          index_group_name  section_name  garment_group_name  alive  Buy
# 0                       2            18                   8      1    0
# 1                       2            14                   4      1    0
# 2                       2            21                  14      1    0
# 3                       2            21                  14      1    0
# 4                       2            14                   4      1    0
# ...                   ...           ...                 ...    ...  ...
# 1257925                 2            13                   5      1    1
# 1257926                 2            21                   5      1    1
# 1257927                 2            15                  14      0    1
# 1257928                 2            17                  11      1    1
# 1257929                 2            17                  11      1    1
#
# [1257930 rows x 19 columns]

# %%
#打亂資料
from sklearn.utils import shuffle
under = shuffle(under)
under
# Out:
#          FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 687322    0       0                   0                       1          1
# 428181    0       0                   0                       1          4
# 868486    1       1                   0                       2          5
# 771165    0       0                   0                       1          2
# 399962    0       0                   0                       1          3
# ...      ..     ...                 ...                     ...        ...
# 865444    0       0                   0                       1          2
# 164451    0       0                   0                       1          2
# 1048268   1       1                   0                       2          4
# 55101     1       1                   0                       2          1
# 316941    1       1                   0                       2          1
#
#          attribute  prod_name  product_type_name  product_group_name  \
# 687322           3         47                  7                   8
# 428181           3         24                 25                   6
# 868486           3        154                 17                   2
# 771165           3         52                 31                   6
# 399962           3        189                 28                   3
# ...            ...        ...                ...                 ...
# 865444           3        158                 30                   2
# 164451           3         64                 35                   3
# 1048268          3         79                 33                   8
# 55101            3        190                 24                   5
# 316941           3         53                 17                   2
#
#          graphical_appearance_name  colour_group_name  \
# 687322                           8                  5
# 428181                           4                 11
# 868486                           8                  1
# 771165                           8                  1
# 399962                           8                 14
# ...                            ...                ...
# 865444                           2                  3
# 164451                           8                  1
# 1048268                          7                  1
# 55101                            8                 14
# 316941                           8                  1
#
#          perceived_colour_value_name  department_name  index_name  \
# 687322                             3               12           4
# 428181                             4               32           4
# 868486                             0               41           4
# 771165                             0               41           4
# 399962                             2               26           5
# ...                              ...              ...         ...
# 865444                             4               11           3
# 164451                             0               26           5
# 1048268                            0                6           4
# 55101                              2               36           2
# 316941                             0               41           4
#
#          index_group_name  section_name  garment_group_name  alive  Buy
# 687322                  2            16                  16      0    1
# 428181                  2            17                  11      1    0
# 868486                  2            17                  11      1    1
# 771165                  2            17                  11      1    1
# 399962                  3            11                   4      0    0
# ...                   ...           ...                 ...    ...  ...
# 865444                  2             7                  15      1    1
# 164451                  3            11                   4      1    0
# 1048268                 2            16                  16      1    1
# 55101                   2            18                   8      1    0
# 316941                  2            17                  11      1    0
#
# [1257930 rows x 19 columns]

# %% [markdown]
# # under完XGB

# %%
y_train = under['Buy']
y_train
# Out:
# 687322     1
# 428181     0
# 868486     1
# 771165     1
# 399962     0
#           ..
# 865444     1
# 164451     0
# 1048268    1
# 55101      0
# 316941     0
# Name: Buy, Length: 1257930, dtype: uint8

# %%
X_train = under.drop('Buy',axis=1)
X_train
# Out:
#          FN  Active  club_member_status  fashion_news_frequency  age_class  \
# 687322    0       0                   0                       1          1
# 428181    0       0                   0                       1          4
# 868486    1       1                   0                       2          5
# 771165    0       0                   0                       1          2
# 399962    0       0                   0                       1          3
# ...      ..     ...                 ...                     ...        ...
# 865444    0       0                   0                       1          2
# 164451    0       0                   0                       1          2
# 1048268   1       1                   0                       2          4
# 55101     1       1                   0                       2          1
# 316941    1       1                   0                       2          1
#
#          attribute  prod_name  product_type_name  product_group_name  \
# 687322           3         47                  7                   8
# 428181           3         24                 25                   6
# 868486           3        154                 17                   2
# 771165           3         52                 31                   6
# 399962           3        189                 28                   3
# ...            ...        ...                ...                 ...
# 865444           3        158                 30                   2
# 164451           3         64                 35                   3
# 1048268          3         79                 33                   8
# 55101            3        190                 24                   5
# 316941           3         53                 17                   2
#
#          graphical_appearance_name  colour_group_name  \
# 687322                           8                  5
# 428181                           4                 11
# 868486                           8                  1
# 771165                           8                  1
# 399962                           8                 14
# ...                            ...                ...
# 865444                           2                  3
# 164451                           8                  1
# 1048268                          7                  1
# 55101                            8                 14
# 316941                           8                  1
#
#          perceived_colour_value_name  department_name  index_name  \
# 687322                             3               12           4
# 428181                             4               32           4
# 868486                             0               41           4
# 771165                             0               41           4
# 399962                             2               26           5
# ...                              ...              ...         ...
# 865444                             4               11           3
# 164451                             0               26           5
# 1048268                            0                6           4
# 55101                              2               36           2
# 316941                             0               41           4
#
#          index_group_name  section_name  garment_group_name  alive
# 687322                  2            16                  16      0
# 428181                  2            17                  11      1
# 868486                  2            17                  11      1
# 771165                  2            17                  11      1
# 399962                  3            11                   4      0
# ...                   ...           ...                 ...    ...
# 865444                  2             7                  15      1
# 164451                  3            11                   4      1
# 1048268                 2            16                  16      1
# 55101                   2            18                   8      1
# 316941                  2            17                  11      1
#
# [1257930 rows x 18 columns]

# %%
from xgboost.sklearn import XGBClassifier

xgbc = XGBClassifier(        
        n_estimators=8,     #樹的個數
        learning_rate= 0.1,    # 如同學習率 
        max_depth=6,       # 構建樹的深度，越大越容易過擬合    
        subsample=1,         # 隨機取樣訓練樣本 訓練例項的子取樣比
        gamma=0,         # 用於控制是否後剪枝的引數,越大越保守，一般0.1、0.2這樣子
        reg_lambda=1,          # 控制模型複雜度的權重值的L2正則化項引數，引數越大，模型越不容易過擬合。
        max_delta_step=0,        #最大增量步長，我們允許每個樹的權重估計。
        colsample_bytree=1,         # 生成樹時進行的列取樣 
        min_child_weight=1, 
                     # 這個引數預設是 1，是每個葉子裡面 h 的和至少是多少，對正負樣本不均衡時的 0-1 分類而言
                     # 假設 h 在 0.01 附近，min_child_weight 為 1 意味著葉子節點中最少需要包含 100 個樣本。
                     #這個引數非常影響結果，控制葉子節點中二階導的和的最小值，該引數值越小，越容易 overfitting。
        seed=1000         #隨機種子
#       reg_alpha=0,        # L1 正則項引數
#       scale_pos_weight=1,        #如果取值大於0的話，在類別樣本不平衡的情況下有助於快速收斂。平衡正負權重
#       objective= 'multi:softmax',         #多分類的問題 指定學習任務和相應的學習目標
#       num_class=10,        # 類別數，多分類與 multisoftmax 並用
#       silent=0 ,        # 設定成1則沒有執行資訊輸出，最好是設定為0.是否在執行升級時列印訊息。
#       nthread=4,        # cpu 執行緒數 預設最大
#       eval_metric= 'auc'
)

#xgbc = XGBClassifier(max_depth=5,learning_rate=0.1,n_estimators=160,silent=True,objective='multi:softmax')
#xgbc = XGBClassifier()
# Out:
# D:\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
xgbc.fit(X_train, y_train)
XGB_pred=xgbc.predict(X_test)
print(XGB_pred)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [22:09:19] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0 1 0 ... 1 1 0]

# %%
XGBtrain_score=xgbc.score(X_train, y_train)
print(XGBtrain_score)
# Out:
# 0.6165136374838027

# %%
XGBtest_score=xgbc.score(X_test,y_test)
print('The Accuracy of XGBOOST Classifier on testing set:', XGBtest_score)
# Out:
# The Accuracy of XGBOOST Classifier on testing set: 0.5488488882824817

# %%
# Sckit-Learn
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,XGB_pred))
print(confusion_matrix(y_test,XGB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.55      0.70  18152401
#            1       0.03      0.68      0.05    309708
#
#     accuracy                           0.55  18462109
#    macro avg       0.51      0.62      0.38  18462109
# weighted avg       0.97      0.55      0.69  18462109
#
# [[9920952 8231449]
#  [  97752  211956]]

# %% [markdown]
# # LGBM

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import LabelBinarizer

# %%
import lightgbm as lgb
lgbmc = lgb.LGBMClassifier()

# %%
lgbmc.fit(X_train, y_train)
LGBM_pred=lgbmc.predict(X_test)
print(LGBM_pred)
# Out:
# [0 1 0 ... 0 1 0]

# %%
LGBMtrain_score=lgbmc.score(X_train, y_train)
print(LGBMtrain_score)
# Out:
# 0.6590692645854698

# %%
LGBMtest_score=lgbmc.score(X_test,y_test)
print('The Accuracy of LightGBM Classifier on testing set:', LGBMtest_score)
# Out:
# The Accuracy of LightGBM Classifier on testing set: 0.6853675276210318

# %%
print(classification_report(y_test,LGBM_pred))
print(confusion_matrix(y_test,LGBM_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.81  18152401
#            1       0.03      0.63      0.06    309708
#
#     accuracy                           0.69  18462109
#    macro avg       0.51      0.66      0.44  18462109
# weighted avg       0.97      0.69      0.80  18462109
#
# [[12458315  5694086]
#  [  114693   195015]]
